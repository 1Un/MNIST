# %% [markdown]
# <a href="https://colab.research.google.com/github/1Un/MNIST/blob/master/64_10cnn_mnist_lenet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://engmrk.com/wp-content/uploads/2018/09/LeNet_Original_Image.jpg)

# %% [markdown]
# ![alt text](https://engmrk.com/wp-content/uploads/2018/09/LeNEt_Summary_Table.jpg)

# %%
import torch
import random
import numpy as np
import torchvision.datasets
MNIST_train = torchvision.datasets.MNIST('./', download=True, train=True)
MNIST_test = torchvision.datasets.MNIST('./', download=True, train=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Processing...
# Done!

# %%
X_train = MNIST_train.train_data
y_train = MNIST_train.train_labels
X_test = MNIST_test.test_data
y_test = MNIST_test.test_labels
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:55: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:45: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:60: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:50: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")

# %%
len(y_train), len(y_test)
# Out:
# (60000, 10000)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0, :, :])
plt.show()
print(y_train[0])
# Out:
# tensor(5)

# %%
X_train.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
X_train = X_train.unsqueeze(1).float()
X_test = X_test.unsqueeze(1).float()

# %%
X_train.shape
# отличие от полносвязанной сети, которая видела картинку как один вектор длинный,
# мы хотим в конволюционную сеть передавать картинку как трёхмерный тензор.
# Первый канал -- это глубина картинки, в черно-белой картинке это 1
# канал с яркостью серого пикселя. А в RGB картинке будут RGB каналы.
# Соответственно, мы должны нашу картинку, которая на вход пришла (она просто "28 на 28"),
# разжать до "1 на 28 на 28". Вот мы это и делаем -- мы делаем X_train.unsqueeze,
# а здесь ставим индекс: "а в каком же измерении мы хотим разжать".
# То есть X_train у нас -- тензор из 60 000 картинок 28 на 28,
# а мы хотим чтобы было 60 000 на 1 на 28 на 28, и то же самое мы делаем с тестом.
# Out:
# torch.Size([60000, 1, 28, 28])

# %%
class LeNet5(torch.nn.Module):
    def __init__(self,neurons):
        super(LeNet5, self).__init__()
        #conv 2d называется так как матрица у нас двумерная  
        self.conv1 = torch.nn.Conv2d(
            in_channels=1, out_channels=6, kernel_size=5, padding=2)
        self.act1  = torch.nn.Tanh()
        self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
       
        self.conv2 = torch.nn.Conv2d(
            in_channels=6, out_channels=16, kernel_size=5, padding=0)
        self.act2  = torch.nn.Tanh()
        self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        
        #изображение в 1 вектор растянем в forward а пока в конструкторе прдеставим что это уже сделано
        self.fc1   = torch.nn.Linear(5 * 5 * 16, neurons)
        self.act3  = torch.nn.Tanh()
        
        # self.fc2   = torch.nn.Linear(neurons, neurons-36)
        # self.act4  = torch.nn.Tanh()
        
        self.fc3   = torch.nn.Linear(neurons, 10)
    
    #x - входной тензор, т.е. батч из картинок 
    def forward(self, x):
        
        x = self.conv1(x)
        x = self.act1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.act2(x)
        x = self.pool2(x)
        
        #преобразуем наш тенхор к нужной размерности x.size(0) - размер батча 
        #а дальше тензор одномерный очевидно что бы получить этот размер надо
        #просто перемножить 3 размерности
        x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))

        x = self.fc1(x)
        x = self.act3(x)
        # x = self.fc2(x)
        # x = self.act4(x)
        x = self.fc3(x)
        
        return x

# %%
# def sum_par(model):
#   s=0
#   for i in model.parameters():
#     #print(i)
#     print(len(i.reshape(-1)))
#     s+=len(i.reshape(-1))
#   return s
# print('sum=',sum_par(lenet5))
#========

# lenet5= LeNet5()
# import torchsummary
# print("Все параметры сети:")
# torchsummary.summary(lenet5.cuda(),(1,28,28))
# #(1,28,28) - размер входного изображения 


def study(lenet5,X_test,y_test,X_train,y_train,batch_size = 5000):  
  #!nvidia-smi
  device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
  lenet5 = lenet5.to(device)
  loss = torch.nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(lenet5.parameters(), lr=1.0e-3)
  

  test_accuracy_history = []
  test_loss_history = []

  X_test = X_test.to(device)
  y_test = y_test.to(device)

  for epoch in range(100):
      order = np.random.permutation(len(X_train))
      for start_index in range(0, len(X_train), batch_size):
          optimizer.zero_grad()
          
          batch_indexes = order[start_index:start_index+batch_size]
          
          X_batch = X_train[batch_indexes].to(device)
          y_batch = y_train[batch_indexes].to(device)
          
          preds = lenet5.forward(X_batch) 
          
          loss_value = loss(preds, y_batch)
          loss_value.backward()
          
          optimizer.step()
          
      test_preds = lenet5.forward(X_test)
      test_loss_history.append(loss(test_preds, y_test).data.cpu())

      accuracy = (test_preds.argmax(dim=1) == y_test).float().mean().data.cpu()
      test_accuracy_history.append(accuracy)

      if epoch%15==0:
        print('epoch=',epoch,'\taccuracy=',accuracy)
  return test_loss_history,test_accuracy_history

# %%
test_loss_history=[]
test_accuracy_history=[]
# !nvidia-smi
for i in range(64,9,-2):
  lenet5= LeNet5(i)  
  import torchsummary
  print("Все параметры сети:")
  torchsummary.summary(lenet5.cuda(),(1,28,28))
  print('=====',i,'=====')
  test_loss_history1,test_accuracy_history1=study(lenet5,X_test,y_test,X_train,y_train,batch_size = 5000)
  test_loss_history.append(test_loss_history1)
  test_accuracy_history.append(test_accuracy_history1)
# Out:
# Mon Apr 27 09:57:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 64]          25,664
#               Tanh-8                   [-1, 64]               0
#             Linear-9                   [-1, 10]             650
# ================================================================
# Total params: 28,886
# Trainable params: 28,886
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.22
# ----------------------------------------------------------------
# ===== 64 =====
# epoch= 0 	accuracy= tensor(0.7299)
# epoch= 15 	accuracy= tensor(0.9717)
# epoch= 30 	accuracy= tensor(0.9828)
# epoch= 45 	accuracy= tensor(0.9859)
# epoch= 60 	accuracy= tensor(0.9887)
# epoch= 75 	accuracy= tensor(0.9885)
# epoch= 90 	accuracy= tensor(0.9890)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 62]          24,862
#               Tanh-8                   [-1, 62]               0
#             Linear-9                   [-1, 10]             630
# ================================================================
# Total params: 28,064
# Trainable params: 28,064
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.22
# ----------------------------------------------------------------
# ===== 62 =====
# epoch= 0 	accuracy= tensor(0.8098)
# epoch= 15 	accuracy= tensor(0.9716)
# epoch= 30 	accuracy= tensor(0.9815)
# epoch= 45 	accuracy= tensor(0.9842)
# epoch= 60 	accuracy= tensor(0.9856)
# epoch= 75 	accuracy= tensor(0.9867)
# epoch= 90 	accuracy= tensor(0.9882)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 60]          24,060
#               Tanh-8                   [-1, 60]               0
#             Linear-9                   [-1, 10]             610
# ================================================================
# Total params: 27,242
# Trainable params: 27,242
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.22
# ----------------------------------------------------------------
# ===== 60 =====
# epoch= 0 	accuracy= tensor(0.7280)
# epoch= 15 	accuracy= tensor(0.9688)
# epoch= 30 	accuracy= tensor(0.9815)
# epoch= 45 	accuracy= tensor(0.9860)
# epoch= 60 	accuracy= tensor(0.9874)
# epoch= 75 	accuracy= tensor(0.9891)
# epoch= 90 	accuracy= tensor(0.9904)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 58]          23,258
#               Tanh-8                   [-1, 58]               0
#             Linear-9                   [-1, 10]             590
# ================================================================
# Total params: 26,420
# Trainable params: 26,420
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.21
# ----------------------------------------------------------------
# ===== 58 =====
# epoch= 0 	accuracy= tensor(0.7216)
# epoch= 15 	accuracy= tensor(0.9602)
# epoch= 30 	accuracy= tensor(0.9791)
# epoch= 45 	accuracy= tensor(0.9857)
# epoch= 60 	accuracy= tensor(0.9876)
# epoch= 75 	accuracy= tensor(0.9883)
# epoch= 90 	accuracy= tensor(0.9891)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 56]          22,456
#               Tanh-8                   [-1, 56]               0
#             Linear-9                   [-1, 10]             570
# ================================================================
# Total params: 25,598
# Trainable params: 25,598
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.21
# ----------------------------------------------------------------
# ===== 56 =====
# epoch= 0 	accuracy= tensor(0.7624)
# epoch= 15 	accuracy= tensor(0.9721)
# epoch= 30 	accuracy= tensor(0.9820)
# epoch= 45 	accuracy= tensor(0.9866)
# epoch= 60 	accuracy= tensor(0.9878)
# epoch= 75 	accuracy= tensor(0.9892)
# epoch= 90 	accuracy= tensor(0.9902)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 54]          21,654
#               Tanh-8                   [-1, 54]               0
#             Linear-9                   [-1, 10]             550
# ================================================================
# Total params: 24,776
# Trainable params: 24,776
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.21
# ----------------------------------------------------------------
# ===== 54 =====
# epoch= 0 	accuracy= tensor(0.7505)
# epoch= 15 	accuracy= tensor(0.9700)
# epoch= 30 	accuracy= tensor(0.9825)
# epoch= 45 	accuracy= tensor(0.9868)
# epoch= 60 	accuracy= tensor(0.9883)
# epoch= 75 	accuracy= tensor(0.9890)
# epoch= 90 	accuracy= tensor(0.9901)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 52]          20,852
#               Tanh-8                   [-1, 52]               0
#             Linear-9                   [-1, 10]             530
# ================================================================
# Total params: 23,954
# Trainable params: 23,954
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------
# ===== 52 =====
# epoch= 0 	accuracy= tensor(0.7308)
# epoch= 15 	accuracy= tensor(0.9676)
# epoch= 30 	accuracy= tensor(0.9820)
# epoch= 45 	accuracy= tensor(0.9852)
# epoch= 60 	accuracy= tensor(0.9866)
# epoch= 75 	accuracy= tensor(0.9884)
# epoch= 90 	accuracy= tensor(0.9891)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 50]          20,050
#               Tanh-8                   [-1, 50]               0
#             Linear-9                   [-1, 10]             510
# ================================================================
# Total params: 23,132
# Trainable params: 23,132
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------
# ===== 50 =====
# epoch= 0 	accuracy= tensor(0.7356)
# epoch= 15 	accuracy= tensor(0.9695)
# epoch= 30 	accuracy= tensor(0.9809)
# epoch= 45 	accuracy= tensor(0.9860)
# epoch= 60 	accuracy= tensor(0.9880)
# epoch= 75 	accuracy= tensor(0.9889)
# epoch= 90 	accuracy= tensor(0.9896)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 48]          19,248
#               Tanh-8                   [-1, 48]               0
#             Linear-9                   [-1, 10]             490
# ================================================================
# Total params: 22,310
# Trainable params: 22,310
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------
# ===== 48 =====
# epoch= 0 	accuracy= tensor(0.7852)
# epoch= 15 	accuracy= tensor(0.9706)
# epoch= 30 	accuracy= tensor(0.9815)
# epoch= 45 	accuracy= tensor(0.9854)
# epoch= 60 	accuracy= tensor(0.9870)
# epoch= 75 	accuracy= tensor(0.9879)
# epoch= 90 	accuracy= tensor(0.9879)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 46]          18,446
#               Tanh-8                   [-1, 46]               0
#             Linear-9                   [-1, 10]             470
# ================================================================
# Total params: 21,488
# Trainable params: 21,488
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.19
# ----------------------------------------------------------------
# ===== 46 =====
# epoch= 0 	accuracy= tensor(0.7128)
# epoch= 15 	accuracy= tensor(0.9639)
# epoch= 30 	accuracy= tensor(0.9804)
# epoch= 45 	accuracy= tensor(0.9845)
# epoch= 60 	accuracy= tensor(0.9864)
# epoch= 75 	accuracy= tensor(0.9883)
# epoch= 90 	accuracy= tensor(0.9890)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 44]          17,644
#               Tanh-8                   [-1, 44]               0
#             Linear-9                   [-1, 10]             450
# ================================================================
# Total params: 20,666
# Trainable params: 20,666
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.19
# ----------------------------------------------------------------
# ===== 44 =====
# epoch= 0 	accuracy= tensor(0.7589)
# epoch= 15 	accuracy= tensor(0.9707)
# epoch= 30 	accuracy= tensor(0.9835)
# epoch= 45 	accuracy= tensor(0.9867)
# epoch= 60 	accuracy= tensor(0.9878)
# epoch= 75 	accuracy= tensor(0.9891)
# epoch= 90 	accuracy= tensor(0.9899)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 42]          16,842
#               Tanh-8                   [-1, 42]               0
#             Linear-9                   [-1, 10]             430
# ================================================================
# Total params: 19,844
# Trainable params: 19,844
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.19
# ----------------------------------------------------------------
# ===== 42 =====
# epoch= 0 	accuracy= tensor(0.7217)
# epoch= 15 	accuracy= tensor(0.9647)
# epoch= 30 	accuracy= tensor(0.9812)
# epoch= 45 	accuracy= tensor(0.9860)
# epoch= 60 	accuracy= tensor(0.9886)
# epoch= 75 	accuracy= tensor(0.9897)
# epoch= 90 	accuracy= tensor(0.9906)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 40]          16,040
#               Tanh-8                   [-1, 40]               0
#             Linear-9                   [-1, 10]             410
# ================================================================
# Total params: 19,022
# Trainable params: 19,022
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.18
# ----------------------------------------------------------------
# ===== 40 =====
# epoch= 0 	accuracy= tensor(0.7206)
# epoch= 15 	accuracy= tensor(0.9622)
# epoch= 30 	accuracy= tensor(0.9809)
# epoch= 45 	accuracy= tensor(0.9832)
# epoch= 60 	accuracy= tensor(0.9864)
# epoch= 75 	accuracy= tensor(0.9875)
# epoch= 90 	accuracy= tensor(0.9885)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 38]          15,238
#               Tanh-8                   [-1, 38]               0
#             Linear-9                   [-1, 10]             390
# ================================================================
# Total params: 18,200
# Trainable params: 18,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.18
# ----------------------------------------------------------------
# ===== 38 =====
# epoch= 0 	accuracy= tensor(0.6981)
# epoch= 15 	accuracy= tensor(0.9670)
# epoch= 30 	accuracy= tensor(0.9795)
# epoch= 45 	accuracy= tensor(0.9836)
# epoch= 60 	accuracy= tensor(0.9857)
# epoch= 75 	accuracy= tensor(0.9868)
# epoch= 90 	accuracy= tensor(0.9881)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 36]          14,436
#               Tanh-8                   [-1, 36]               0
#             Linear-9                   [-1, 10]             370
# ================================================================
# Total params: 17,378
# Trainable params: 17,378
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.18
# ----------------------------------------------------------------
# ===== 36 =====
# epoch= 0 	accuracy= tensor(0.7519)
# epoch= 15 	accuracy= tensor(0.9639)
# epoch= 30 	accuracy= tensor(0.9793)
# epoch= 45 	accuracy= tensor(0.9853)
# epoch= 60 	accuracy= tensor(0.9872)
# epoch= 75 	accuracy= tensor(0.9883)
# epoch= 90 	accuracy= tensor(0.9888)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 34]          13,634
#               Tanh-8                   [-1, 34]               0
#             Linear-9                   [-1, 10]             350
# ================================================================
# Total params: 16,556
# Trainable params: 16,556
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.17
# ----------------------------------------------------------------
# ===== 34 =====
# epoch= 0 	accuracy= tensor(0.6848)
# epoch= 15 	accuracy= tensor(0.9631)
# epoch= 30 	accuracy= tensor(0.9794)
# epoch= 45 	accuracy= tensor(0.9842)
# epoch= 60 	accuracy= tensor(0.9873)
# epoch= 75 	accuracy= tensor(0.9887)
# epoch= 90 	accuracy= tensor(0.9890)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 32]          12,832
#               Tanh-8                   [-1, 32]               0
#             Linear-9                   [-1, 10]             330
# ================================================================
# Total params: 15,734
# Trainable params: 15,734
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.17
# ----------------------------------------------------------------
# ===== 32 =====
# epoch= 0 	accuracy= tensor(0.6805)
# epoch= 15 	accuracy= tensor(0.9612)
# epoch= 30 	accuracy= tensor(0.9774)
# epoch= 45 	accuracy= tensor(0.9831)
# epoch= 60 	accuracy= tensor(0.9854)
# epoch= 75 	accuracy= tensor(0.9862)
# epoch= 90 	accuracy= tensor(0.9877)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 30]          12,030
#               Tanh-8                   [-1, 30]               0
#             Linear-9                   [-1, 10]             310
# ================================================================
# Total params: 14,912
# Trainable params: 14,912
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.17
# ----------------------------------------------------------------
# ===== 30 =====
# epoch= 0 	accuracy= tensor(0.6556)
# epoch= 15 	accuracy= tensor(0.9635)
# epoch= 30 	accuracy= tensor(0.9798)
# epoch= 45 	accuracy= tensor(0.9837)
# epoch= 60 	accuracy= tensor(0.9859)
# epoch= 75 	accuracy= tensor(0.9877)
# epoch= 90 	accuracy= tensor(0.9886)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 28]          11,228
#               Tanh-8                   [-1, 28]               0
#             Linear-9                   [-1, 10]             290
# ================================================================
# Total params: 14,090
# Trainable params: 14,090
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.17
# ----------------------------------------------------------------
# ===== 28 =====
# epoch= 0 	accuracy= tensor(0.6897)
# epoch= 15 	accuracy= tensor(0.9667)
# epoch= 30 	accuracy= tensor(0.9787)
# epoch= 45 	accuracy= tensor(0.9826)
# epoch= 60 	accuracy= tensor(0.9855)
# epoch= 75 	accuracy= tensor(0.9873)
# epoch= 90 	accuracy= tensor(0.9877)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 26]          10,426
#               Tanh-8                   [-1, 26]               0
#             Linear-9                   [-1, 10]             270
# ================================================================
# Total params: 13,268
# Trainable params: 13,268
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# ===== 26 =====
# epoch= 0 	accuracy= tensor(0.7028)
# epoch= 15 	accuracy= tensor(0.9559)
# epoch= 30 	accuracy= tensor(0.9750)
# epoch= 45 	accuracy= tensor(0.9824)
# epoch= 60 	accuracy= tensor(0.9851)
# epoch= 75 	accuracy= tensor(0.9863)
# epoch= 90 	accuracy= tensor(0.9874)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 24]           9,624
#               Tanh-8                   [-1, 24]               0
#             Linear-9                   [-1, 10]             250
# ================================================================
# Total params: 12,446
# Trainable params: 12,446
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# ===== 24 =====
# epoch= 0 	accuracy= tensor(0.7053)
# epoch= 15 	accuracy= tensor(0.9620)
# epoch= 30 	accuracy= tensor(0.9777)
# epoch= 45 	accuracy= tensor(0.9838)
# epoch= 60 	accuracy= tensor(0.9868)
# epoch= 75 	accuracy= tensor(0.9880)
# epoch= 90 	accuracy= tensor(0.9890)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 22]           8,822
#               Tanh-8                   [-1, 22]               0
#             Linear-9                   [-1, 10]             230
# ================================================================
# Total params: 11,624
# Trainable params: 11,624
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# ===== 22 =====
# epoch= 0 	accuracy= tensor(0.7122)
# epoch= 15 	accuracy= tensor(0.9604)
# epoch= 30 	accuracy= tensor(0.9773)
# epoch= 45 	accuracy= tensor(0.9824)
# epoch= 60 	accuracy= tensor(0.9852)
# epoch= 75 	accuracy= tensor(0.9874)
# epoch= 90 	accuracy= tensor(0.9877)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 20]           8,020
#               Tanh-8                   [-1, 20]               0
#             Linear-9                   [-1, 10]             210
# ================================================================
# Total params: 10,802
# Trainable params: 10,802
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# ===== 20 =====
# epoch= 0 	accuracy= tensor(0.6491)
# epoch= 15 	accuracy= tensor(0.9525)
# epoch= 30 	accuracy= tensor(0.9756)
# epoch= 45 	accuracy= tensor(0.9816)
# epoch= 60 	accuracy= tensor(0.9850)
# epoch= 75 	accuracy= tensor(0.9864)
# epoch= 90 	accuracy= tensor(0.9872)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 18]           7,218
#               Tanh-8                   [-1, 18]               0
#             Linear-9                   [-1, 10]             190
# ================================================================
# Total params: 9,980
# Trainable params: 9,980
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# ===== 18 =====
# epoch= 0 	accuracy= tensor(0.5644)
# epoch= 15 	accuracy= tensor(0.9447)
# epoch= 30 	accuracy= tensor(0.9747)
# epoch= 45 	accuracy= tensor(0.9813)
# epoch= 60 	accuracy= tensor(0.9845)
# epoch= 75 	accuracy= tensor(0.9865)
# epoch= 90 	accuracy= tensor(0.9878)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 16]           6,416
#               Tanh-8                   [-1, 16]               0
#             Linear-9                   [-1, 10]             170
# ================================================================
# Total params: 9,158
# Trainable params: 9,158
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# ===== 16 =====
# epoch= 0 	accuracy= tensor(0.5072)
# epoch= 15 	accuracy= tensor(0.9558)
# epoch= 30 	accuracy= tensor(0.9742)
# epoch= 45 	accuracy= tensor(0.9815)
# epoch= 60 	accuracy= tensor(0.9837)
# epoch= 75 	accuracy= tensor(0.9864)
# epoch= 90 	accuracy= tensor(0.9873)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 14]           5,614
#               Tanh-8                   [-1, 14]               0
#             Linear-9                   [-1, 10]             150
# ================================================================
# Total params: 8,336
# Trainable params: 8,336
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.14
# ----------------------------------------------------------------
# ===== 14 =====
# epoch= 0 	accuracy= tensor(0.4428)
# epoch= 15 	accuracy= tensor(0.9464)
# epoch= 30 	accuracy= tensor(0.9723)
# epoch= 45 	accuracy= tensor(0.9802)
# epoch= 60 	accuracy= tensor(0.9832)
# epoch= 75 	accuracy= tensor(0.9845)
# epoch= 90 	accuracy= tensor(0.9856)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 12]           4,812
#               Tanh-8                   [-1, 12]               0
#             Linear-9                   [-1, 10]             130
# ================================================================
# Total params: 7,514
# Trainable params: 7,514
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.14
# ----------------------------------------------------------------
# ===== 12 =====
# epoch= 0 	accuracy= tensor(0.4108)
# epoch= 15 	accuracy= tensor(0.9422)
# epoch= 30 	accuracy= tensor(0.9712)
# epoch= 45 	accuracy= tensor(0.9788)
# epoch= 60 	accuracy= tensor(0.9836)
# epoch= 75 	accuracy= tensor(0.9858)
# epoch= 90 	accuracy= tensor(0.9883)
# Все параметры сети:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#               Tanh-2            [-1, 6, 28, 28]               0
#          AvgPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               Tanh-5           [-1, 16, 10, 10]               0
#          AvgPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                   [-1, 10]           4,010
#               Tanh-8                   [-1, 10]               0
#             Linear-9                   [-1, 10]             110
# ================================================================
# Total params: 6,692
# Trainable params: 6,692
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.14
# ----------------------------------------------------------------
# ===== 10 =====
# epoch= 0 	accuracy= tensor(0.5475)
# epoch= 15 	accuracy= tensor(0.9416)
# epoch= 30 	accuracy= tensor(0.9639)
# epoch= 45 	accuracy= tensor(0.9725)
# epoch= 60 	accuracy= tensor(0.9780)
# epoch= 75 	accuracy= tensor(0.9816)
# epoch= 90 	accuracy= tensor(0.9836)

# %%
import pandas as pd
import numpy as np

# %%
test_loss_history_np=np.array(test_loss_history)
test_accuracy_history_np=np.array(test_accuracy_history)

# %%
x1=np.copy(test_loss_history_np)
x2=np.copy(test_accuracy_history_np)
#показание лосс функции на последней эпохе
print(test_loss_history_np[:,-1])
# Out:
# [0.03210466 0.03301898 0.03109245 0.03174412 0.03146103 0.03239636
#  0.0304182  0.03378058 0.03251073 0.03429789 0.03119645 0.03398218
#  0.0345243  0.03455108 0.03427903 0.03332478 0.03775729 0.03664541
#  0.03740745 0.0393565  0.03868147 0.03841249 0.04387629 0.04307655
#  0.04770161 0.05159583 0.05831509 0.07479028]

# %%
#точность предсказания на последней эпохе 
print(test_accuracy_history_np[:,-1])
# Out:
# [0.9892     0.98829997 0.99069995 0.98889995 0.9896     0.9899
#  0.9895     0.9899     0.9891     0.9896     0.99009997 0.98969996
#  0.9884     0.98819995 0.9887     0.9896     0.988      0.9888
#  0.9881     0.9888     0.98899996 0.9887     0.988      0.9885
#  0.98759997 0.98709995 0.98859996 0.98499995]

# %%
# save numpy array as csv file
from numpy import asarray
from numpy import savetxt
# define data
# save to csv file
savetxt('64-10_test_loss_history_np.csv', test_loss_history_np, delimiter=',')
savetxt('64-10_test_accuracy_history_np.csv', test_accuracy_history_np, delimiter=',')

# load numpy array from csv file
# from numpy import loadtxt
# # load array
# test_loss_history_np = loadtxt('./test_loss_history_np.csv', delimiter=',')
# test_accuracy_history_np = loadtxt('./test_accuracy_history_np.csv', delimiter=',')

# %%
# from numpy import genfromtxt
# test_accuracy_history_np = genfromtxt('/content/120-64_test_accuracy_history_np.csv', delimiter=',')
# test_loss_history_np = genfromtxt('/content/120-64_test_loss_history_np.csv', delimiter=',')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(np.arange(64, 9 , -2),test_accuracy_history_np[:,-1])  

plt.gca().invert_xaxis()

ax.set_xlabel('Число нейрнов в слое')

ax.set_ylabel('Точность  предсказания сети')
plt.savefig('4.png')

print('максимальная точность на последнй эпохе обучения ',test_accuracy_history_np[:,-1].max())
#print('т.е. когда число нейронов было ',120-5*(test_accuracy_history_np[:,-1].argmax()+1)) 
print('минимальная точность  на последнй эпохе обучения',test_accuracy_history_np[:,-1].min())
#print('т.е. когда число нейронов было ',120-5*(test_accuracy_history_np[:,-1].argmin()))
# Out:
# максимальная точность на последнй эпохе обучения  0.99069995
# минимальная точность  на последнй эпохе обучения 0.98499995
